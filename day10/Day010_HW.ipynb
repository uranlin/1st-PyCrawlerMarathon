# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
import requests
import os
from bs4 import BeautifulSoup
url = 'https://www.ptt.cc/bbs/WJSN/M.1575730303.A.24E.html'
resp = requests.get(url, cookies={'over18': '1'})
soup = BeautifulSoup(resp.text)
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>[日記] 191204-191206 Luda SNS 更新 - 看板 WJSN - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content="191204 Luda官咖更新
# [Luda :D] [:(]哼 UJUNG和我玩吧
# 2019.12.04. 22:14
# 我現在
# 木乃伊? 是殭屍喔
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="[日記] 191204-191206 Luda SNS 更新" property="og:title"/>
# <meta content="191204 Luda官咖更新
# [Luda :D] [:(]哼 UJUNG和我玩吧
# 2019.12.04. 22:14
# 我現在
# 木乃伊? 是殭屍喔
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/WJSN/M.1575730303.A.24E.html" rel="canonical"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/WJSN/index.html"><span class="board-label">看板 </span>WJSN</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="navigation-container">
# <div class="bbs-content" id="navigation">
# <a class="board" href="/bbs/WJSN/index.html">返回看板</a>
# <div class="bar"></div>
# </div>
# </div>
# <div id="main-container">
# <div class="bbs-screen bbs-content" id="main-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">pkkcyc ()</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">WJSN</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[日記] 191204-191206 Luda SNS 更新</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sat Dec  7 22:51:40 2019</span></div>
# <span class="f3 hl">191204 Luda官咖更新</span>
# <span class="f5 hl">[Luda :D] [:(]哼 UJUNG和我玩吧</span>
# <span class="f0 hl">2019.12.04. 22:14</span>
#
# 我現在
# 木乃伊? 是殭屍喔
# UJUNG在做什麼呢?
# <a href="https://i.imgur.com/VdFr9rj.jpg" rel="nofollow" target="_blank">https://i.imgur.com/VdFr9rj.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="VdFr9rj" lang="en"><a href="//imgur.com/VdFr9rj"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><span class="f0 hl"><a href="http://cafe.daum.net/WJSNcosmic/biBt/264" rel="nofollow" target="_blank">http://cafe.daum.net/WJSNcosmic/biBt/264</a> </span>
# <span class="f3 hl">191206 Luda官咖更新</span>
# <span class="f5 hl">[Luda :D] 耳罩...</span>
# <span class="f0 hl">2019.12.06. 21:36</span>
#
# 恩熙給的耳罩...
# 覺得很適合但...
# 像Pengsoo呢..哈k
# <a href="https://i.imgur.com/Jo7ym55.jpg" rel="nofollow" target="_blank">https://i.imgur.com/Jo7ym55.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="Jo7ym55" lang="en"><a href="//imgur.com/Jo7ym55"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><span class="f0 hl"><a href="http://cafe.daum.net/WJSNcosmic/biBt/268" rel="nofollow" target="_blank">http://cafe.daum.net/WJSNcosmic/biBt/268</a> </span>
# <span class="f0 hl">翻譯:<a class="__cf_email__" data-cfemail="11617a7a72687251414545" href="/cdn-cgi/l/email-protection">[email protected]</a></span>
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 220.134.245.90 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/WJSN/M.1575730303.A.24E.html" rel="nofollow" target="_blank">https://www.ptt.cc/bbs/WJSN/M.1575730303.A.24E.html</a>
# </span><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">mrblue53453</span><span class="f3 push-content">: 可愛</span><span class="push-ipdatetime"> 12/08 00:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">hebe0508</span><span class="f3 push-content">: 別嘟嘴了 太可愛了</span><span class="push-ipdatetime"> 12/08 00:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">biobirst</span><span class="f3 push-content">: 小可愛</span><span class="push-ipdatetime"> 12/08 10:46
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">candn</span><span class="f3 push-content">: 動漫走出來的錯覺！Luda！</span><span class="push-ipdatetime"> 12/08 16:38
# </span></div></div>
# <div data-longpollurl="/v1/longpoll?id=c55599b48f09af721fc310140280cf706b59f957" data-offset="1113" data-pollurl="/poll/WJSN/M.1575730303.A.24E.html?cacheKey=2085-806182997&amp;offset=1113&amp;offset-sig=489a41dac5f73e05166ad5f2533b6b05e4af8a2a" id="article-polling"></div>
# </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %% [markdown]
# ## Grab + PyQuery

# %%
from grab import Grab
from pyquery import PyQuery as pq

g = Grab()
resp = g.go(url)
doc = pq(resp.body)
print(title, doc)
# Out:
# <title>[日記] 191204-191206 Luda SNS 更新 - 看板 WJSN - 批踢踢實業坊</title>
#  <html>
# 	<head>
# 		<meta charset="utf-8"/>
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1"/>
#
# <title>[日記] 191204-191206 Luda SNS 更新 - 看板 WJSN - 批踢踢實業坊</title>
# <meta name="robots" content="all"/>
# <meta name="keywords" content="Ptt BBS 批踢踢"/>
# <meta name="description" content="191204 Luda官咖更新&#10;[Luda :D] [:(]哼 UJUNG和我玩吧&#10;2019.12.04. 22:14&#10;我現在&#10;木乃伊? 是殭屍喔&#10;"/>
# <meta property="og:site_name" content="Ptt 批踢踢實業坊"/>
# <meta property="og:title" content="[日記] 191204-191206 Luda SNS 更新"/>
# <meta property="og:description" content="191204 Luda官咖更新&#10;[Luda :D] [:(]哼 UJUNG和我玩吧&#10;2019.12.04. 22:14&#10;我現在&#10;木乃伊? 是殭屍喔&#10;"/>
# <link rel="canonical" href="https://www.ptt.cc/bbs/WJSN/M.1575730303.A.24E.html"/>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css"/>
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen"/>
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css"/>
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen"/>
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print"/>
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>›</span>
# 		<a class="board" href="/bbs/WJSN/index.html"><span class="board-label">看板 </span>WJSN</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/WJSN/index.html">返回看板</a>
# 		<div class="bar"/>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">pkkcyc ()</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">WJSN</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[日記] 191204-191206 Luda SNS 更新</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sat Dec  7 22:51:40 2019</span></div>
# <span class="f3 hl">191204 Luda官咖更新</span>
#
# <span class="f5 hl">[Luda :D] [:(]哼 UJUNG和我玩吧</span>
# <span class="f0 hl">2019.12.04. 22:14</span>
#
# 我現在
# 木乃伊? 是殭屍喔
# UJUNG在做什麼呢?
# <a href="https://i.imgur.com/VdFr9rj.jpg" target="_blank" rel="nofollow">https://i.imgur.com/VdFr9rj.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" lang="en" data-id="VdFr9rj"><a href="//imgur.com/VdFr9rj"/></blockquote><script async="" src="//s.imgur.com/min/embed.js" charset="utf-8"/></div><span class="f0 hl"><a href="http://cafe.daum.net/WJSNcosmic/biBt/264" target="_blank" rel="nofollow">http://cafe.daum.net/WJSNcosmic/biBt/264</a> </span>
#
# <span class="f3 hl">191206 Luda官咖更新</span>
#
# <span class="f5 hl">[Luda :D] 耳罩...</span>
# <span class="f0 hl">2019.12.06. 21:36</span>
#
# 恩熙給的耳罩...
# 覺得很適合但...
# 像Pengsoo呢..哈k
# <a href="https://i.imgur.com/Jo7ym55.jpg" target="_blank" rel="nofollow">https://i.imgur.com/Jo7ym55.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" lang="en" data-id="Jo7ym55"><a href="//imgur.com/Jo7ym55"/></blockquote><script async="" src="//s.imgur.com/min/embed.js" charset="utf-8"/></div><span class="f0 hl"><a href="http://cafe.daum.net/WJSNcosmic/biBt/268" target="_blank" rel="nofollow">http://cafe.daum.net/WJSNcosmic/biBt/268</a> </span>
#
# <span class="f0 hl">翻譯:<a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="f6869d9d958f95b6a6a2a2">[email protected]</a></span>
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 220.134.245.90 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/WJSN/M.1575730303.A.24E.html" target="_blank" rel="nofollow">https://www.ptt.cc/bbs/WJSN/M.1575730303.A.24E.html</a>
# </span><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">mrblue53453</span><span class="f3 push-content">: 可愛</span><span class="push-ipdatetime"> 12/08 00:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">hebe0508</span><span class="f3 push-content">: 別嘟嘴了 太可愛了</span><span class="push-ipdatetime"> 12/08 00:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">biobirst</span><span class="f3 push-content">: 小可愛</span><span class="push-ipdatetime"> 12/08 10:46
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">candn</span><span class="f3 push-content">: 動漫走出來的錯覺！Luda！</span><span class="push-ipdatetime"> 12/08 16:38
# </span></div></div>
#
#     <div id="article-polling" data-pollurl="/poll/WJSN/M.1575730303.A.24E.html?cacheKey=2085-806182997&amp;offset=1113&amp;offset-sig=489a41dac5f73e05166ad5f2533b6b05e4af8a2a" data-longpollurl="/v1/longpoll?id=c55599b48f09af721fc310140280cf706b59f957" data-offset="1113"/>
#
#
#
# </div>
#
#
#
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"/><script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"/>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"/>
#
#     </body>
# </html>
