# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 利用 urllib 套件的 urlretrieve 方法下載檔案
# * 了解 Python File I/O 讀檔、寫檔的用法
# * 能用運用資源管理器 With Statement 優化寫法

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
import json
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text
#response
data = json.loads(response)
print('有{}筆資料\n'.format(len(data)))
for d in data:
    print(d['title'])
# Out:
# 有30筆資料
#
# 好像買太小了...
# 我養的是工讀生？🤔
# 散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩
# 貓咪沒在尊重男友
# 如果當初這樣做 或許結局就能不同了吧
# 自嗨小橘貓
# #圖多 可愛喵喵們(⁎⁍̴̛ᴗ⁍̴̛⁎)
# 可以幫幫我推上熱門嗎急尋狗啟示
# 我家阿咪的特技
# 你們吸貓，我被貓吸
# #貓 擁有狗靈魂的貓
# 兔兔的睡姿⋯⋯
# 寵物過世碰到的外套
# 我家的紅貴賓到底是不是人轉世？
# 一隻會傳球的貓
# 請問⋯妳是在哈囉？
# 來嘛~~來吸我啊~
# 基隆瑞芳深澳坑走失協找 拜託❗️❗️
# 虎爺公的細漢欸（小弟）
# 你有看過這隻狗嗎？
# 我養了三隻蟲？🐛
# 中壢/米克斯狗女兒走失
# 睡到投降的傻布偶小貓
# 送養
# 淘寶寵物用品開箱&心得📦🐱
# #協尋 玄鳳鸚鵡（已找到愛鳥 謝謝大家 謝謝好心人）
# 她是真的不是假的🌚
# 吉娃娃才不吉敗咧
# 公貓結紮紀錄
# #圖 板橋貓咪走失

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
number = 1
for d in data:
    print('{:}:'.format(number))
    print('標題:    ', d['title'])
    print('貼文時間:', d['createdAt'])
    print('留言人數:', len(d['mediaMeta']))
    print('按讚人數:', d['likeCount'])
    number += 1
# Out:
# 1:
# 標題:     好像買太小了...
# 貼文時間: 2019-12-01T0
# 留言人數: 6
# 按讚人數: 3117
# 2:
# 標題:     我養的是工讀生？🤔
# 貼文時間: 2019-12-01T0
# 留言人數: 8
# 按讚人數: 456
# 3:
# 標題:     散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩
# 貼文時間: 2019-12-02T0
# 留言人數: 0
# 按讚人數: 300
# 4:
# 標題:     貓咪沒在尊重男友
# 貼文時間: 2019-12-01T1
# 留言人數: 2
# 按讚人數: 87
# 5:
# 標題:     如果當初這樣做 或許結局就能不同了吧
# 貼文時間: 2019-12-01T0
# 留言人數: 0
# 按讚人數: 51
# 6:
# 標題:     自嗨小橘貓
# 貼文時間: 2019-11-30T2
# 留言人數: 6
# 按讚人數: 45
# 7:
# 標題:     #圖多 可愛喵喵們(⁎⁍̴̛ᴗ⁍̴̛⁎)
# 貼文時間: 2019-12-01T0
# 留言人數: 36
# 按讚人數: 38
# 8:
# 標題:     可以幫幫我推上熱門嗎急尋狗啟示
# 貼文時間: 2019-12-01T1
# 留言人數: 10
# 按讚人數: 34
# 9:
# 標題:     我家阿咪的特技
# 貼文時間: 2019-11-30T1
# 留言人數: 3
# 按讚人數: 32
# 10:
# 標題:     你們吸貓，我被貓吸
# 貼文時間: 2019-11-30T1
# 留言人數: 1
# 按讚人數: 30
# 11:
# 標題:     #貓 擁有狗靈魂的貓
# 貼文時間: 2019-12-01T1
# 留言人數: 11
# 按讚人數: 21
# 12:
# 標題:     兔兔的睡姿⋯⋯
# 貼文時間: 2019-12-01T0
# 留言人數: 4
# 按讚人數: 21
# 13:
# 標題:     寵物過世碰到的外套
# 貼文時間: 2019-12-01T0
# 留言人數: 0
# 按讚人數: 20
# 14:
# 標題:     我家的紅貴賓到底是不是人轉世？
# 貼文時間: 2019-12-01T0
# 留言人數: 0
# 按讚人數: 18
# 15:
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

#print(len(data))
likecount=0
mediameta=0

for d in data:
#    print(d['likeCount'])
    likecount += d['likeCount']
    mediameta += len(d['mediaMeta'])

like_mean = likecount / len(data)
mediameta_mean = mediameta / len(data)

print('平均留言人數:{:.2f}'.format(mediameta_mean))
print('平均案讚人數:{:.2f}'.format(like_mean))
# Out:
# 平均留言人數:7.10
# 平均案讚人數:157.07
